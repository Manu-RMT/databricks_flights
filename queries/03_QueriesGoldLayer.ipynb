# %%
import sys
# -----------------------------
# Ajouter le repo au Python Path
# -----------------------------
sys.path.append("/Workspace/Users/mandu543@gmail.com/databricks_flights")

from src.Communs.utils import *

# %%
df = getTable(spark,GOLD_ZONE,"dim_flights_airports")
display(df)

# %%
df = getTable(spark,GOLD_ZONE,"dim_flights_flights")
display(df)

# %%
spark.sql("DELETE FROM "+GOLD_ZONE+".dim_flights_flights WHERE flight_id = 'F0110'")
