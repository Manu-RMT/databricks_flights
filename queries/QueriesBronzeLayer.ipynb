# %%
import sys
# -----------------------------
# Ajouter le repo au Python Path
# -----------------------------
sys.path.append("/Workspace/Users/mandu543@gmail.com/databricks_flights")

from conf.config import *

# %%
bronze_path_bookings = f"{BRONZE_DATA}bookings/"
table = spark.sql(f" SELECT * from delta.`{bronze_path_bookings}`")
display(table)

# %%
bronze_path_flights = f"{BRONZE_DATA}flights"
table = spark.sql(f" SELECT * from delta.`{bronze_path_flights}`")
display(table)

# %%
bronze_path_customers = f"{BRONZE_DATA}customers"
table = spark.sql(f" SELECT * from delta.`{bronze_path_customers}`")
display(table)

# %%
bronze_path_airports = f"{BRONZE_DATA}airports"
table = spark.sql(f" SELECT * from delta.`{bronze_path_airports}`")
display(table)
