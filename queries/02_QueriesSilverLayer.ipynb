# %%
import sys
# -----------------------------
# Ajouter le repo au Python Path
# -----------------------------
sys.path.append("/Workspace/Users/mandu543@gmail.com/databricks_flights")

from src.Communs.utils import *

# %%
df = getTable(spark,SILVER_ZONE,"silver_flights_airports")
display(df)

#Si on relance le Pipeline, on peut avoir que la modiedDate ne change pas => OK

# %%
df = getTable(spark,SILVER_ZONE,"silver_flights_bookings")
display(df)

# %%
df = getTable(spark,SILVER_ZONE,"silver_flights_flights")
display(df)

# %%
df = getTable(spark,SILVER_ZONE,"silver_flights_customers")
display(df)
