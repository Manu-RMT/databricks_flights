# %%
source_data = [
    {"src_data" : "Bookings"},
    {"src_data" : "Flights"},
    {"src_data" : "Customers"},
    {"src_data" : "Airports"}
]

display(source_data)

# %%
dbutils.jobs.taskValues.set(key="output_source_data", value = source_data)
