# %%
# %sql
CREATE SCHEMA IF NOT EXISTS raw_flights;
CREATE VOLUME if NOT EXISTS workspace.raw_flights.raw_data;

# %%
# permet de créer des dossiers
dbutils.fs.mkdirs("/Volumes/workspace/raw_flights/raw_data/Bookings")
dbutils.fs.mkdirs("/Volumes/workspace/raw_flights/raw_data/Airports")
dbutils.fs.mkdirs("/Volumes/workspace/raw_flights/raw_data/Customers")
dbutils.fs.mkdirs("/Volumes/workspace/raw_flights/raw_data/Flights")
