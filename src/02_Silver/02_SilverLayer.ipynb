# %% [markdown]
# ## DEMO METHODE NOTEBOOOKS

# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
import sys
# -----------------------------
# Ajouter le repo au Python Path
# -----------------------------
sys.path.append("/Workspace/Users/mandu543@gmail.com/databricks_flights")

from src.Communs.utils import *

# %%
src_bookings = "bookings"
src_airports = "airports"
src_flights = "flights"
src_customers = "customers"

bronze_path_bookings = f"{BRONZE_DATA}{src_bookings}"
bronze_path_airports = f"{BRONZE_DATA}{src_airports}"
bronze_path_flights = f"{BRONZE_DATA}{src_flights}"
bronze_path_customers = f"{BRONZE_DATA}{src_customers}"

# %%
df_bookings = spark.read.format("delta").load(bronze_path_bookings)
df_airports = spark.read.format("delta").load(bronze_path_airports)
df_flights = spark.read.format("delta").load(bronze_path_flights)
df_customers = spark.read.format("delta").load(bronze_path_customers)

display(df_bookings)
display(df_airports)
display(df_flights)
display(df_customers)

# %% [markdown]
# ### SANS DLT

# %%
df_bookings = df_bookings.withColumn("booking_date", to_date(col("booking_date"),"yyyy-MM-dd")) \
                        .withColumn("amount", col("amount").cast("double")) \
                        .withColumn("modifiedDate",current_timestamp()) \
                        .drop("_rescued_data")
display(df_bookings)
